# %% [markdown]
# # 01 — Data Ingestion
#
# Scrape FastAPI docs, chunk by heading, and build search indices.

# %%
import sys; sys.path.insert(0, "..")
from ingest.run import run_pipeline
run_pipeline(library="fastapi")

# %%
import json
with open("../data/processed/fastapi/chunks.json") as f:
    chunks = json.load(f)
print(f"Indexed {len(chunks)} chunks")
chunks[0]
