# %% [markdown]
# # 04 - RAG Evaluation
#
# LLM-as-judge relevance scoring and model comparison.

# %%
import json, os, sys
sys.path.insert(0, "..")
from app.evaluation import evaluate_relevance, compare_models, comparison_summary
import pandas as pd

# %%
# Sample questions
test_questions = [
    "How do I create a path operation?",
    "What is a dependency in FastAPI?",
    "How do I handle errors?",
]

# %%
# Compare models
results = compare_models(test_questions, models=["gpt-4o-mini", "gpt-4o"])
print(results.to_string())

# %%
summary = comparison_summary(results)
print("\nComparison Summary:")
print(summary.to_string(float_format="%.2f"))
